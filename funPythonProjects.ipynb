# %% [markdown]
# # Password Authentication using Python

# %%
import getpass

database = {"theNattyCoder":"12345", "AveragePythonEnjoyer":"98765"}
username = input("Enter your username: \n")
password = getpass.getpass("Enter your password: \n")

for i in database.keys():
    if username == i:
        while password != database.get(i):
            password = getpass.getpass("Enter your password again! \n")
        break
print("Valid password :D")
# Out:
# Enter your username:
# theNattyCoder
# Enter your password:
# ········
# Enter your password again!
# ········
# Enter your password again!
# ········
# Valid password :D

# %% [markdown]
# # Defang IP Address using Python

# %%
def ip_address(address):
    new_address = ""
    split_address = address.split(".")
    separator = "[.]"
    new_address = separator.join(split_address)
    return new_address
IPadr = input("Enter your IP address: \n")
ipaddress = ip_address(IPadr)
print(ipaddress)
# Out:
# Enter your IP address:
# 192.168.1.1
# 192[.]168[.]1[.]1

# %% [markdown]
# # Bar Graph using Matplotlib in Python

# %%
import matplotlib.pyplot as plt

labels = ('Python', 'Java', 'C#', 'PHP', 'R')
index = (1, 2, 3, 4, 5)
sizes = [45, 30, 25, 15, 20]

plt.bar(index, sizes, tick_label = labels)

plt.xlabel('Usage')
plt.ylabel('Programming Language')
plt.show()

# %% [markdown]
# # Avatar Logo in Python using Turtle

# %%
from turtle import *
speed(0)
bgcolor('dark blue')
color('light blue')
hideturtle()
n = 1
p = True
while True:
    circle(n)
    if p:
        n -= 1
    else:
        n += 1
    if n == 0 or n == 60:
        p = not p
    left(1)
    forward(3)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16664\863773104.py in <module>
#      15         p = not p
#      16     left(1)
# ---> 17     forward(3)
#
# ~\anaconda3\lib\turtle.py in forward(distance)
#
# Terminator:

# %% [markdown]
# # Pie Charts using Matplotlib in Python

# %%
import matplotlib.pyplot as plt
labels = ('Python', 'Java', 'Scala', 'C#')
sizes = [45, 30, 15, 10]
plt.pie(sizes, labels = labels, autopct = '%1.f%%', counterclock = False, startangle = 105)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Real-time Currency Converter with Python

# %%
pip install forex_python
# Out:
# Collecting forex_pythonNote: you may need to restart the kernel to use updated packages.
#
#   Downloading forex_python-1.8-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: requests in c:\users\msi\anaconda3\lib\site-packages (from forex_python) (2.28.1)
# Collecting simplejson
#   Downloading simplejson-3.18.4-cp39-cp39-win_amd64.whl (74 kB)
#      -------------------------------------- 74.9/74.9 kB 375.9 kB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msi\anaconda3\lib\site-packages (from requests->forex_python) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\msi\anaconda3\lib\site-packages (from requests->forex_python) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\msi\anaconda3\lib\site-packages (from requests->forex_python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msi\anaconda3\lib\site-packages (from requests->forex_python) (3.3)
# Installing collected packages: simplejson, forex_python
# Successfully installed forex_python-1.8 simplejson-3.18.4

# %%
from forex_python.converter import CurrencyRates
c = CurrencyRates()
amount = int(input("Enter the amount: "))
from_currency = input("From Currency: ").upper()
to_currency = input("To Currency: ").upper()

print(from_currency, " to ", to_currency, amount)
result = c.convert(from_currency, to_currency, amount)
print(result)
# Out:
# Enter the amount: 100
# From Currency: USD
# To Currency: INR
# USD  to  INR 100
# 8232.55277957039

# %% [markdown]
# # Extract Text from PDF with Python

# %%
pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ------------------------------------ 232.6/232.6 kB 309.2 kB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\msi\anaconda3\lib\site-packages (from PyPDF2) (4.3.0)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2
pdf = open("cybrone.pdf", "rb")
reader = PyPDF2.PdfReader(pdf)
page = reader.pages[0]
print(page.extract_text())
# Out:
# F I RST DRONE BASED M I T E  D E T E CT I ON I N THE WORL DF I RST DRONE BASED MI T E  D E T E CT I ON I N THE WORL D
# ﻮ أﺼﻞ وﺣﻮدهٍ أﻋﺻﺎﺑﺘﻲ
#  اﻟﻤﻜﺎﻓﺢ اﻷول ﻷﺑﻮ ﻓﺮوةVisit us
# S a k i e t  E z z i t ,  S f a x ,  T u n i s i a
# Contact us
# 9 9 9 0 2 7 2 6
# S a b t i t u n i s i a @ g m a i l . c o m
# Connect with us
# Since 2023c y b r o n e
# ﻤﺎﻪ ﻣﻮﺣﻚ
# ﺎں ﺣﻮده اﻮر
# ﺻﺎﻚ  ﻋﺎ....

# %% [markdown]
# # Validate Anagrams using Python

# %%
def anagram(word1, word2):
    word1 = word1.lower()
    word2 = word2.lower()
    return sorted(word1) == sorted(word2)

print(anagram('cinema', 'iceman'))
print(anagram('cool', 'loco'))
print(anagram('men', 'women'))
# Out:
# True
# True
# False

# %% [markdown]
# # Contact Book in Python

# %%
names = []
phone_numbers = []
num = int(input("Enter number of contact you want to save: "))
for i in range(num):
    name = input("Name: ")
    phone_number = input("Phone Number: ")
    names.append(name)
    phone_numbers.append(phone_number)
    
print("\nName \t\t Phone Number\n")
for i in range(num):
    print("{}\t\t\t{}".format(names[i], phone_numbers[i]))
search_term = input("\nEnter search term: ")
print("Search result: ")
if search_term in names:
    index = names.index(search_term)
    phone_number = phone_numbers[index]
    print("Name: {}, Phone Number: {}".format(search_term, phone_number))
else:
    print("Name Not Found!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16664\3010412908.py in <module>
#       1 names = []
#       2 phone_numbers = []
# ----> 3 num = int(input("Enter number of contact you want to save: "))
#       4 for i in range(num):
#       5     name = input("Name: ")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Pick a Random Card using Python

# %%
import random
cards = ["Diamonds", "Spades", "Hearts", "Clubs"]
ranks = [2, 3, 4, 5, 6, 7, 8, 9, 10, "Jack", "Queen", "King", "Ace"]

def pick_a_card():
    card = random.choices(cards)
    rank = random.choices(ranks)
    return(f"The {rank} of {card}")
print(pick_a_card())
# Out:
# The [4] of ['Diamonds']

# %% [markdown]
# # Fidget Spinner game with Python

# %%
from turtle import *
state = {'turn': 0}
def spinner():
    clear()
    angle = state['turn']/10
    right(angle)
    forward(100)
    dot(120, 'red')
    back(100)
    right(120)
    forward(100)
    dot(120, 'green')
    back(100)
    right(120)
    forward(100)
    dot(120, 'blue')
    back(100)
    right(120)
    update()
    
def animate():
    if state['turn']>0:
        state['turn'] -= 1
    spinner()
    ontimer(animate, 20)
    
def flick():
    state['turn'] += 10
setup(420,420,370,0)
hideturtle()
tracer(False)
width(20)
onkey(flick, 'space')
listen()
animate()
done()
